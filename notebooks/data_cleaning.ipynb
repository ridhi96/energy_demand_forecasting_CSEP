# %%
import pandas as pd
from datetime import datetime
import sys
sys.path.append('../')
from utils.data_clean import convert_to_previous_date, clean_date, missing_dates #adding cleaning functions from data_clean.py file

# %%
df1 = pd.read_csv('/Users/ridhipurohit/Documents/GitHub/energy_project_CSEP/energy_modeling/data/tr_data_1/data_2013_14.csv')

# %%
print(df1.size)
df1.dtypes
# Out:
# 4628
# date                   object
# NR_peak_demand          int64
# WR_peak_demand          int64
# SR_peak_demand          int64
# ER_peak_demand          int64
# NER_peak_demand         int64
# Total_peak_demand       int64
# NR_peak_shortage        int64
# WR_peak_shortage        int64
# SR_peak_shortage        int64
# ER_peak_shortage        int64
# NER_peak_shortage       int64
# Total_peak_shortage     int64
# dtype: object

# %%
df1['date'] = df1['date'].apply(clean_date)

# %%
df1 = df1.sort_values(by='date', ascending=True)
df1.head()
# Out:
#            date  NR_peak_demand  WR_peak_demand  SR_peak_demand  \
# 19   2013-01-02           35136           36914           31623
# 322  2013-01-03           36462           38019           32126
# 170  2013-01-04           37787           37776           32573
# 198  2013-01-05           36636           36784           31636
# 236  2013-01-06           35764           36419           29973
#
#      ER_peak_demand  NER_peak_demand  Total_peak_demand  NR_peak_shortage  \
# 19            14794             1761             120228              1195
# 322           15083             1797             123487              2049
# 170           14592             1861             124589              1695
# 198           14804             1804             121664              1985
# 236           14118             1798             118072              1695
#
#      WR_peak_shortage  SR_peak_shortage  ER_peak_shortage  NER_peak_shortage  \
# ...

# %%
df1['date'] = df1['date'].str.replace('2013-01', '2014-01') # fixed data error that had initial few days in Jan 2014 tagged to 2013
df1 = df1.sort_values(by='date', ascending=True)
df1.head()
# Out:
#            date  NR_peak_demand  WR_peak_demand  SR_peak_demand  \
# 270  2013-04-01           27482           34592           28778
# 347  2013-04-02           28291           36791           30828
# 24   2013-04-03           29845           36496           30407
# 189  2013-04-04           31321           37155           28887
# 141  2013-04-05           32182           37303           30916
#
#      ER_peak_demand  NER_peak_demand  Total_peak_demand  NR_peak_shortage  \
# 270           14256             1557             106665              1500
# 347           14308             1659             111877              1694
# 24            14061             1594             112403              2010
# 189           13563             1660             112586              2108
# 141           14520             1537             116458              2036
#
#      WR_peak_shortage  SR_peak_shortage  ER_peak_shortage  NER_peak_shortage  \
# ...

# %%
df1['date'] = convert_to_previous_date(df1['date'])

# %%
missing = missing_dates(datetime(2013,3,31), datetime(2014,3,30) ,df1['date'])
print(missing)
# Out:
# ['2013-05-30', '2013-06-03', '2013-06-28', '2013-07-27', '2013-08-13', '2013-08-28', '2013-08-29', '2013-09-14', '2013-09-20', '2013-09-23', '2013-10-15']

# %%
df2 = pd.read_csv('/Users/ridhipurohit/Documents/GitHub/energy_project_CSEP/energy_modeling/data/tr_data_1/data_2014_15.csv')

# %%
df2['date'] = df2['date'].apply(clean_date)
df2 = df2.sort_values(by='date', ascending=True)
df2.head(3)
# Out:
#            date  NR_peak_demand  WR_peak_demand  SR_peak_demand  \
# 289  2014-04-01           31972           37858           34569
# 366  2014-04-02           33202           37992           34872
# 26   2014-04-03           33998           40210           35661
#
#      ER_peak_demand  NER_peak_demand  Total_peak_demand  NR_peak_shortage  \
# 289         15969.0             1848           122216.0              2453
# 366         15585.0             1908           123559.0              1550
# 26          15893.0             1808           127570.0              2000
#
#      WR_peak_shortage  SR_peak_shortage  ER_peak_shortage  NER_peak_shortage  \
# 289               193              2018               600                244
# 366               177              2235               200                213
# 26                203              3027               269                268
#
#      Total_peak_shortage
# 289                 5508
# 366                 4375
# ...

# %%
df2['date'] = convert_to_previous_date(df2['date'])
df2.head(1)
# Out:
#           date  NR_peak_demand  WR_peak_demand  SR_peak_demand  \
# 289 2014-03-31           31972           37858           34569
#
#      ER_peak_demand  NER_peak_demand  Total_peak_demand  NR_peak_shortage  \
# 289         15969.0             1848           122216.0              2453
#
#      WR_peak_shortage  SR_peak_shortage  ER_peak_shortage  NER_peak_shortage  \
# 289               193              2018               600                244
#
#      Total_peak_shortage
# 289                 5508

# %%
df2.tail(1)
# Out:
#           date  NR_peak_demand  WR_peak_demand  SR_peak_demand  \
# 301 2015-03-30           31781           40281           35178
#
#      ER_peak_demand  NER_peak_demand  Total_peak_demand  NR_peak_shortage  \
# 301         13467.0             2101           122808.0              1032
#
#      WR_peak_shortage  SR_peak_shortage  ER_peak_shortage  NER_peak_shortage  \
# 301               158              1757                 0                188
#
#      Total_peak_shortage
# 301                 3135

# %%
missing = missing_dates(datetime(2014,3,31), datetime(2015,3,30) ,df2['date'])
print(missing)
# Out:
# []

# %%
df3 = pd.read_csv('/Users/ridhipurohit/Documents/GitHub/energy_project_CSEP/energy_modeling/data/tr_data_1/data_2015_16.csv')

# %%
df3['date'] = df3['date'].apply(clean_date)
df3 = df3.sort_values(by='date', ascending=True)
df3.head(3)
# Out:
#            date  NR_peak_demand  WR_peak_demand  SR_peak_demand  \
# 333  2015-04-01           31230           41710           35576
# 172  2015-04-02           32412           41097           35009
# 86   2015-04-03           35166           41293           34712
#
#      ER_peak_demand  NER_peak_demand  Total_peak_demand  NR_peak_shortage  \
# 333           16244             2036             126797              1268
# 172           16733             1962             127213              1583
# 86            16622             1963             129755              2964
#
#      WR_peak_shortage  SR_peak_shortage  ER_peak_shortage  NER_peak_shortage  \
# 333               378              1936               161                232
# 172               226              1387               378                202
# 86                234              1278               331                284
#
#      Total_peak_shortage
# 333                 3975
# 172                 3776
# ...

# %%
df3['date'] = convert_to_previous_date(df3['date'])
df3.head(1)
# Out:
#           date  NR_peak_demand  WR_peak_demand  SR_peak_demand  \
# 333 2015-03-31           31230           41710           35576
#
#      ER_peak_demand  NER_peak_demand  Total_peak_demand  NR_peak_shortage  \
# 333           16244             2036             126797              1268
#
#      WR_peak_shortage  SR_peak_shortage  ER_peak_shortage  NER_peak_shortage  \
# 333               378              1936               161                232
#
#      Total_peak_shortage
# 333                 3975

# %%
df3.tail(1)
# Out:
#         date  NR_peak_demand  WR_peak_demand  SR_peak_demand  ER_peak_demand  \
# 4 2016-03-30           35686           42775           37371           16965
#
#    NER_peak_demand  Total_peak_demand  NR_peak_shortage  WR_peak_shortage  \
# 4             2356             135153              1733               107
#
#    SR_peak_shortage  ER_peak_shortage  NER_peak_shortage  Total_peak_shortage
# 4               525               273                 85                 2723

# %%
missing = missing_dates(datetime(2015,3,31), datetime(2016,3,30) ,df3['date'])
print(missing)
# Out:
# ['2015-04-06', '2015-05-02', '2015-07-03', '2015-07-12', '2015-07-13', '2016-03-07', '2016-03-23', '2016-03-25']

# %%
df3.loc[(df3.loc[:, 'date']=='2015-04-05')& (df3.loc[:, 'NR_peak_demand']==33508), 'date'] = datetime(2015,4,6)

# %%
df4 = pd.read_csv('/Users/ridhipurohit/Documents/GitHub/energy_project_CSEP/energy_modeling/data/tr_data_1/data_2016_17.csv')
df4['date'] = df4['date'].apply(clean_date)
df4 = df4.sort_values(by='date', ascending=True)
df4.head(3)
# Out:
#            date  NR_peak_demand  WR_peak_demand  SR_peak_demand  \
# 51   2016-04-01           36235           42159           37309
# 36   2016-04-02           35798           41783           37609
# 369  2016-04-03           36919           41787           36905
#
#      ER_peak_demand  NER_peak_demand  Total_peak_demand  NR_peak_shortage  \
# 51            17495             1872             135070              1305
# 36            17691             2142             135024              1484
# 369           17538             2243             135392              1546
#
#      WR_peak_shortage  SR_peak_shortage  ER_peak_shortage  NER_peak_shortage  \
# 51                 21               849                 0                402
# 36                 62                 0               500                186
# 369                72                 0               781                 76
#
#      Total_peak_shortage
# 51                  2577
# 36                  2232
# ...

# %%
df4['date'] = convert_to_previous_date(df4['date'])
df4.head(1)
# Out:
#          date  NR_peak_demand  WR_peak_demand  SR_peak_demand  ER_peak_demand  \
# 51 2016-03-31           36235           42159           37309           17495
#
#     NER_peak_demand  Total_peak_demand  NR_peak_shortage  WR_peak_shortage  \
# 51             1872             135070              1305                21
#
#     SR_peak_shortage  ER_peak_shortage  NER_peak_shortage  Total_peak_shortage
# 51               849                 0                402                 2577

# %%
df4.tail(1)
# Out:
#         date  NR_peak_demand  WR_peak_demand  SR_peak_demand  ER_peak_demand  \
# 3 2017-03-30           41418           46958           39712           18661
#
#    NER_peak_demand  Total_peak_demand  NR_peak_shortage  WR_peak_shortage  \
# 3             2176             148925               892                47
#
#    SR_peak_shortage  ER_peak_shortage  NER_peak_shortage  Total_peak_shortage
# 3                 0                 0                156                 1095

# %%
missing = missing_dates(datetime(2016,3,31), datetime(2017,3,30) ,df4['date'])
print(missing)
# Out:
# []

# %%
df5 = pd.read_csv('/Users/ridhipurohit/Documents/GitHub/energy_project_CSEP/energy_modeling/data/tr_data_1/data_2017_18.csv')
df5['date'] = df5['date'].apply(clean_date)
df5 = df5.sort_values(by='date', ascending=True)
df5.head(3)
# Out:
#            date  NR_peak_demand  WR_peak_demand  SR_peak_demand  \
# 39   2017-04-01           41915           47202           39848
# 29   2017-04-02           39991           46566           38975
# 154  2017-04-03           36968           44889           36051
#
#      ER_peak_demand  NER_peak_demand  Total_peak_demand  NR_peak_shortage  \
# 39            19652             2217             150835               478
# 29            19105             1920             146557               639
# 154           18326             1917             138151               846
#
#      WR_peak_shortage  SR_peak_shortage  ER_peak_shortage  NER_peak_shortage  \
# 39                 98                 0               150                146
# 29                 94                94                 0                264
# 154                45                 0                 0                297
#
#      Total_peak_shortage
# 39                   872
# 29                  1091
# ...

# %%
df5['date'] = convert_to_previous_date(df5['date'])
df5.head(1)
# Out:
#          date  NR_peak_demand  WR_peak_demand  SR_peak_demand  ER_peak_demand  \
# 39 2017-03-31           41915           47202           39848           19652
#
#     NER_peak_demand  Total_peak_demand  NR_peak_shortage  WR_peak_shortage  \
# 39             2217             150835               478                98
#
#     SR_peak_shortage  ER_peak_shortage  NER_peak_shortage  Total_peak_shortage
# 39                 0               150                146                  872

# %%
df5.tail(1)
# Out:
#           date  NR_peak_demand  WR_peak_demand  SR_peak_demand  \
# 221 2018-03-30           38831           46083           44122
#
#      ER_peak_demand  NER_peak_demand  Total_peak_demand  NR_peak_shortage  \
# 221           18460             2003             149499               516
#
#      WR_peak_shortage  SR_peak_shortage  ER_peak_shortage  NER_peak_shortage  \
# 221                45                 0                 0                360
#
#      Total_peak_shortage
# 221                  921

# %%
missing = missing_dates(datetime(2017,3,31), datetime(2018,3,30) ,df5['date'])
print(missing)
# Out:
# []

# %%
df6 = pd.read_csv('/Users/ridhipurohit/Documents/GitHub/energy_project_CSEP/energy_modeling/data/tr_data_1/data_2018_19.csv')
df6['date'] = df6['date'].apply(clean_date)
df6 = df6.sort_values(by='date', ascending=True)
df6.head(3)
# Out:
#            date  NR_peak_demand  WR_peak_demand  SR_peak_demand  \
# 141  2018-04-01           39729           45295           43733
# 189  2018-04-02           42215           41524           38591
# 282  2018-04-03           42278           46136           41332
#
#      ER_peak_demand  NER_peak_demand  Total_peak_demand  NR_peak_shortage  \
# 141           17912             2260             148929               834
# 189           14086             2081             138497              1047
# 282           18990             2385             151121               878
#
#      WR_peak_shortage  SR_peak_shortage  ER_peak_shortage  NER_peak_shortage  \
# 141                 0                 0                89                103
# 189                 0                 0                 0                136
# 282                34                 0                 0                 66
#
#      Total_peak_shortage
# 141                 1026
# 189                 1183
# ...

# %%
df6['date'] = convert_to_previous_date(df6['date'])
df6.head(1)
# Out:
#           date  NR_peak_demand  WR_peak_demand  SR_peak_demand  \
# 141 2018-03-31           39729           45295           43733
#
#      ER_peak_demand  NER_peak_demand  Total_peak_demand  NR_peak_shortage  \
# 141           17912             2260             148929               834
#
#      WR_peak_shortage  SR_peak_shortage  ER_peak_shortage  NER_peak_shortage  \
# 141                 0                 0                89                103
#
#      Total_peak_shortage
# 141                 1026

# %%
df6.tail(1)
# Out:
#           date  NR_peak_demand  WR_peak_demand  SR_peak_demand  \
# 253 2019-03-30           41417           49952           46363
#
#      ER_peak_demand  NER_peak_demand  Total_peak_demand  NR_peak_shortage  \
# 253           21269             2459             161460                 0
#
#      WR_peak_shortage  SR_peak_shortage  ER_peak_shortage  NER_peak_shortage  \
# 253                 0                 0                 0                 42
#
#      Total_peak_shortage
# 253                   42

# %%
missing = missing_dates(datetime(2018,3,31), datetime(2019,3,30) ,df6['date'])
print(missing)
# Out:
# []

# %%
df7 = pd.read_csv('/Users/ridhipurohit/Documents/GitHub/energy_project_CSEP/energy_modeling/data/tr_data_1/data_2019_20.csv')
df7['date'] = df7['date'].apply(clean_date)
df7 = df7.sort_values(by='date', ascending=True)
df7.head(3)
# Out:
# Exception occurred for NR WR SR ER NER TOTAL
# Exception occurred for NR WR SR ER NER TOTAL
# Exception occurred for NR WR SR ER NER TOTAL
#            date  NR_peak_demand  WR_peak_demand  SR_peak_demand  \
# 209  2019-04-01           39242           45950           43187
# 240  2019-04-02           42598           49285           46230
# 101  2019-04-03           46342           50278           46949
#
#      ER_peak_demand  NER_peak_demand  Total_peak_demand  NR_peak_shortage  \
# 209           19230             1752             149361               563
# 240           19523             2228             159864               527
# 101           21407             1939             166915               547
#
#      WR_peak_shortage  SR_peak_shortage  ER_peak_shortage  NER_peak_shortage  \
# 209                 0                 0                 0                676
# 240                 0                 0                 0                292
# ...

# %%
df7['date'] = convert_to_previous_date(df7['date'])
df7.head(1)
# Out:
#           date  NR_peak_demand  WR_peak_demand  SR_peak_demand  \
# 209 2019-03-31           39242           45950           43187
#
#      ER_peak_demand  NER_peak_demand  Total_peak_demand  NR_peak_shortage  \
# 209           19230             1752             149361               563
#
#      WR_peak_shortage  SR_peak_shortage  ER_peak_shortage  NER_peak_shortage  \
# 209                 0                 0                 0                676
#
#      Total_peak_shortage
# 209                 1239

# %%
df7.tail(1)
# Out:
#     date  NR_peak_demand  WR_peak_demand  SR_peak_demand  ER_peak_demand  \
# 328  NaT             449               0               0               0
#
#      NER_peak_demand  Total_peak_demand  NR_peak_shortage  WR_peak_shortage  \
# 328               43                492               734               971
#
#      SR_peak_shortage  ER_peak_shortage  NER_peak_shortage  \
# 328               975               315                 36
#
#      Total_peak_shortage
# 328                 3030

# %%
missing = missing_dates(datetime(2019,3,31), datetime(2020,3,30) ,df7['date'])
print(missing)
# Out:
# ['2020-03-28', '2020-03-30']

# %%
df = pd.concat([df1, df2, df3, df4, df5, df6,df7], ignore_index=True)
df.head(1)
# Out:
#         date  NR_peak_demand  WR_peak_demand  SR_peak_demand  ER_peak_demand  \
# 0 2013-03-31           27482           34592           28778         14256.0
#
#    NER_peak_demand  Total_peak_demand  NR_peak_shortage  WR_peak_shortage  \
# 0             1557           106665.0              1500               889
#
#    SR_peak_shortage  ER_peak_shortage  NER_peak_shortage  Total_peak_shortage
# 0              5156               416                355                 8316

# %%
df.tail(1)
# Out:
#      date  NR_peak_demand  WR_peak_demand  SR_peak_demand  ER_peak_demand  \
# 2580  NaT             449               0               0             0.0
#
#       NER_peak_demand  Total_peak_demand  NR_peak_shortage  WR_peak_shortage  \
# 2580               43              492.0               734               971
#
#       SR_peak_shortage  ER_peak_shortage  NER_peak_shortage  \
# 2580               975               315                 36
#
#       Total_peak_shortage
# 2580                 3030

# %%
missing = missing_dates(datetime(2013,3,31), datetime(2020,3,30) ,df['date'])
print(missing)
# Out:
# ['2013-05-30', '2013-06-03', '2013-06-28', '2013-07-27', '2013-08-13', '2013-08-28', '2013-08-29', '2013-09-14', '2013-09-20', '2013-09-23', '2013-10-15', '2015-05-02', '2015-07-03', '2015-07-12', '2015-07-13', '2016-03-07', '2016-03-23', '2016-03-25', '2020-03-28', '2020-03-30']

# %%
df.sort_values(by='date', inplace=True)
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#         date  NR_peak_demand  WR_peak_demand  SR_peak_demand  ER_peak_demand  \
# 0 2013-03-31           27482           34592           28778         14256.0
# 1 2013-04-01           28291           36791           30828         14308.0
# 2 2013-04-02           29845           36496           30407         14061.0
# 3 2013-04-03           31321           37155           28887         13563.0
# 4 2013-04-04           32182           37303           30916         14520.0
#
#    NER_peak_demand  Total_peak_demand  NR_peak_shortage  WR_peak_shortage  \
# 0             1557           106665.0              1500               889
# 1             1659           111877.0              1694              1073
# 2             1594           112403.0              2010               969
# 3             1660           112586.0              2108               793
# 4             1537           116458.0              2036              1167
#
# ...

# %%
df = df.dropna(subset=[df.columns[0]])

# %%
missing = missing_dates(datetime(2013,3,31), datetime(2020,3,30) ,df['date'])
print(missing)
# Out:
# ['2013-05-30', '2013-06-03', '2013-06-28', '2013-07-27', '2013-08-13', '2013-08-28', '2013-08-29', '2013-09-14', '2013-09-20', '2013-09-23', '2013-10-15', '2015-05-02', '2015-07-03', '2015-07-12', '2015-07-13', '2016-03-07', '2016-03-23', '2016-03-25', '2020-03-28', '2020-03-30']

# %%
df.to_csv('combined_data_2013_20.csv', index=False)
